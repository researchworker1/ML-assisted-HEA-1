# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shap
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score  
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
import math

# %%
df = pd.read_csv('HVfeature.csv')
df.head()
# Out:
#       HV  Yang delta  Yang omega  APE mean  Radii local mismatch  Radii gamma  \
# 0  473.0    0.045116    5.286477 -0.001256              2.760331     1.076155
# 1  367.0    0.046148    4.620453 -0.001247              2.661157     1.076253
# 2  418.0    0.045116    4.269184 -0.001256              2.760331     1.076155
# 3  423.0    0.045585    6.106589 -0.001279              2.793388     1.076175
# 4  168.0    0.029846    3.570183  0.001778              1.577597     1.076589
#
#    Configuration entropy  Atomic weight mean  Total weight  Lambda entropy  \
# 0              -0.014697           52.096116   5214.821177       -7.220712
# 1              -0.014697           52.726761   5277.948742       -6.901322
# 2              -0.014697           52.376861   5242.923752       -7.220712
# 3              -0.014697           52.117915   5217.003312       -7.072881
# 4              -0.012590           54.904797   5495.970199      -14.133195
#
# ...

# %%
y = df['HV'].values
X =  df.drop(["HV"], axis=1)
X.head()
# Out:
#    Yang delta  Yang omega  APE mean  Radii local mismatch  Radii gamma  \
# 0    0.045116    5.286477 -0.001256              2.760331     1.076155
# 1    0.046148    4.620453 -0.001247              2.661157     1.076253
# 2    0.045116    4.269184 -0.001256              2.760331     1.076155
# 3    0.045585    6.106589 -0.001279              2.793388     1.076175
# 4    0.029846    3.570183  0.001778              1.577597     1.076589
#
#    Configuration entropy  Atomic weight mean  Total weight  Lambda entropy  \
# 0              -0.014697           52.096116   5214.821177       -7.220712
# 1              -0.014697           52.726761   5277.948742       -6.901322
# 2              -0.014697           52.376861   5242.923752       -7.220712
# 3              -0.014697           52.117915   5217.003312       -7.072881
# 4              -0.012590           54.904797   5495.970199      -14.133195
#
#    Electronegativity delta  ...  Mixing enthalpy  Mean cohesive energy  \
# ...

# %%
model1 = RandomForestRegressor(n_estimators=300, random_state=42, max_features='log2')
model1.fit(X, y)
# Out:
# RandomForestRegressor(max_features='log2', n_estimators=300, random_state=42)

# %%
scores = cross_val_score(model1, X, y, cv=5) 
print(scores.mean())
# Out:
# 0.9011542265508574

# %%
y_pred = cross_val_predict(model1, X, y, cv=5)

# %%
mae = mean_absolute_error(y, y_pred)
mae
# Out:
# 40.55806539130435

# %%
mse = mean_squared_error(y, y_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 70.28684857596922

# %%
model2 = LinearRegression()
model2.fit(X,y)
# Out:
# LinearRegression()

# %%
scores = cross_val_score(model2, X, y, cv=5) 
print(scores.mean())
# Out:
# 0.8031709441199834

# %%
y_pred = cross_val_predict(model2, X, y, cv=5)

# %%
mae = mean_absolute_error(y, y_pred)
mae
# Out:
# 70.78029202590336

# %%
mse = mean_squared_error(y, y_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 95.0268044195107

# %%
model3 = SVR(C=1.5,kernel='linear')
model3.fit(X,y)
# Out:
# SVR(C=1.5, kernel='linear')

# %%
scores = cross_val_score(model3, X, y, cv=5) 
print(scores.mean())
# Out:
# 0.7266305311797943

# %%
y_pred = cross_val_predict(model3, X, y, cv=5)

# %%
mae = mean_absolute_error(y, y_pred)
mae
# Out:
# 81.75593004428951

# %%
mse = mean_squared_error(y, y_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 111.43518057016978

# %%
model4 = GradientBoostingRegressor(n_estimators=500, learning_rate=0.2, random_state=42)
model4.fit(X,y)
# Out:
# GradientBoostingRegressor(learning_rate=0.2, n_estimators=500, random_state=42)

# %%
scores = cross_val_score(model4, X, y, cv=5) 
print(scores.mean())
# Out:
# 0.8861080038629054

# %%
y_pred = cross_val_predict(model4, X, y, cv=5)

# %%
mae = mean_absolute_error(y, y_pred)
mae
# Out:
# 34.235893827117934

# %%
mse = mean_squared_error(y, y_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 75.73983511619923
